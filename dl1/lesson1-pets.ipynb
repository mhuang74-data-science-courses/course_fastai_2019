# %% [markdown]
# # Lesson 1 - What's your pet

# %% [markdown]
# Welcome to lesson 1! For those of you who are using a Jupyter Notebook for the first time, you can learn about this useful tool in a tutorial we prepared specially for you; click `File`->`Open` now and click `00_notebook_tutorial.ipynb`.
#
# In this lesson we will build our first image classifier from scratch, and see if we can achieve world-class results. Let's dive in!
#
# Every notebook starts with the following three lines; they ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# We are going to use the [Oxford-IIIT Pet Dataset](http://www.robots.ox.ac.uk/~vgg/data/pets/) by [O. M. Parkhi et al., 2012](http://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf) which features 12 cat breeds and 25 dogs breeds. Our model will need to learn to differentiate between these 37 distinct categories. According to their paper, the best accuracy they could get in 2012 was 59.21%, using a complex model that was specific to pet detection, with separate "Image", "Head", and "Body" models for the pet photos. Let's see how accurate we can be using deep learning!
#
# We are going to use the `untar_data` function to which we must pass a URL as an argument and which will download and extract the data.

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url: str, fname: Union[pathlib.Path, str] = None, dest: Union[pathlib.Path, str] = None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if it doesn't exist, and un-tgz to folder `dest`.

# %%
# ?URLs
# Out:
# Init signature: URLs()
# Docstring:      Global constants for dataset and model URLs.
# File:           /opt/anaconda3/lib/python3.7/site-packages/fastai/datasets.py
# Type:           type
# Subclasses:

# %%
path = untar_data(URLs.PETS); path
# Out:
# PosixPath('/home/jupyter/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/home/jupyter/.fastai/data/oxford-iiit-pet/images'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-iiit-pet/annotations')]

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %% [markdown]
# The first thing we do when we approach a problem is to take a look at the data. We _always_ need to understand very well what the problem is and what the data looks like before we can figure out how to solve it. Taking a look at the data means understanding how the data directories are structured, what the labels are and what some sample images look like.
#
# The main difference between the handling of image classification datasets is the way labels are stored. In this particular dataset, labels are stored in the filenames themselves. We will need to extract them to be able to classify the images into the correct categories. Fortunately, the fastai library has a handy function made exactly for this, `ImageDataBunch.from_name_re` gets the labels from the filenames using a [regular expression](https://docs.python.org/3.6/library/re.html).

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/home/jupyter/.fastai/data/oxford-iiit-pet/images/japanese_chin_125.jpg'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-iiit-pet/images/British_Shorthair_155.jpg'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-iiit-pet/images/Siamese_56.jpg'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-iiit-pet/images/Bombay_111.jpg'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-iiit-pet/images/pomeranian_11.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).
#
# We will train for 4 epochs (4 cycles through all our data).

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/jupyter/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:00<00:00, 93674026.43it/s]

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5)
#     (8): Linear(in_features=512, out_features=37, bias=True)
#   )
# )

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 04:10 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.354853</th>
#     <th>0.372914</th>
#     <th>0.112314</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.553480</th>
#     <th>0.262723</th>
#     <th>0.081191</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.333336</th>
#     <th>0.253587</th>
#     <th>0.077131</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.250607</th>
#     <th>0.230944</th>
#     <th>0.067659</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# ## Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
# Out:
# <h4 id="_cl_int_plot_top_losses"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L105" class="source_link">[source]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>)</p>
# </blockquote>
# <p>Show images in <code>top_losses</code> along with their prediction, actual, loss, and probability of predicted class.</p>
# <p><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L105" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('american_pit_bull_terrier', 'staffordshire_bull_terrier', 9),
#  ('american_bulldog', 'staffordshire_bull_terrier', 7),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 5),
#  ('Birman', 'Ragdoll', 4),
#  ('Ragdoll', 'Birman', 3),
#  ('Russian_Blue', 'British_Shorthair', 3),
#  ('american_pit_bull_terrier', 'american_bulldog', 3),
#  ('yorkshire_terrier', 'havanese', 3)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 01:07 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.545851</th>
#     <th>0.338339</th>
#     <th>0.108931</th>
#   </tr>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
# Out:
# Min numerical gradient: 1.58E-06

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 02:14 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.239381</th>
#     <th>0.232287</th>
#     <th>0.073072</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.221084</th>
#     <th>0.233255</th>
#     <th>0.066306</th>
#   </tr>
# </table>

# %% [markdown]
# That's a pretty accurate model!

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(),
                                   size=299, bs=bs//2).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /home/jupyter/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 87324346.66it/s]

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.09E-03

# %%
learn.fit_one_cycle(8)
# Out:
# Total time: 24:54 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>4.288064</th>
#     <th>3.847045</th>
#     <th>0.974966</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>4.284026</th>
#     <th>3.843540</th>
#     <th>0.968200</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>4.283794</th>
#     <th>3.848756</th>
#     <th>0.968877</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>4.278901</th>
#     <th>3.860136</th>
#     <th>0.972936</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>4.274846</th>
#     <th>3.852228</th>
#     <th>0.970230</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>4.250903</th>
#     <th>3.844342</th>
#     <th>0.972936</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>4.261718</th>
#     <th>3.849280</th>
#     <th>0.974290</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>4.290558</th>
#     <th>3.855669</th>
#     <th>0.971583</th>
#   </tr>
# </table>

# %%
learn.save('stage-1-50')

# %% [markdown]
# It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 09:15 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>4.270627</th>
#     <th>3.840855</th>
#     <th>0.968877</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>4.262882</th>
#     <th>3.846615</th>
#     <th>0.968877</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>4.339324</th>
#     <th>3.850464</th>
#     <th>0.972936</th>
#   </tr>
# </table>

# %% [markdown]
# If it doesn't, you can always go back to your previous model.

# %%
learn.load('stage-1-50');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)
# Out:
# [('saint_bernard', 'miniature_pinscher', 19),
#  ('newfoundland', 'scottish_terrier', 16),
#  ('samoyed', 'miniature_pinscher', 14),
#  ('Ragdoll', 'pomeranian', 11),
#  ('Russian_Blue', 'pomeranian', 11),
#  ('american_pit_bull_terrier', 'newfoundland', 11),
#  ('keeshond', 'wheaten_terrier', 11),
#  ('Bombay', 'pomeranian', 10),
#  ('american_pit_bull_terrier', 'american_bulldog', 10),
#  ('english_setter', 'havanese', 10),
#  ('great_pyrenees', 'miniature_pinscher', 10),
#  ('scottish_terrier', 'Maine_Coon', 10),
#  ('wheaten_terrier', 'Bombay', 10),
#  ('boxer', 'american_bulldog', 9),
#  ('japanese_chin', 'leonberger', 9),
#  ('leonberger', 'Persian', 9),
#  ('Birman', 'leonberger', 8),
#  ('Sphynx', 'german_shorthaired', 8),
#  ('basset_hound', 'english_cocker_spaniel', 8),
#  ('beagle', 'english_cocker_spaniel', 8),
#  ('english_cocker_spaniel', 'havanese', 8),
#  ('great_pyrenees', 'saint_bernard', 8),
#  ('havanese', 'american_bulldog', 8),
#  ('staffordshire_bull_terrier', 'american_bulldog', 8),
#  ('Abyssinian', 'pomeranian', 7),
#  ('Birman', 'shiba_inu', 7),
#  ('Bombay', 'boxer', 7),
#  ('British_Shorthair', 'pomeranian', 7),
#  ('boxer', 'chihuahua', 7),
#  ('great_pyrenees', 'havanese', 7),
#  ('pomeranian', 'leonberger', 7),
#  ('pug', 'american_bulldog', 7),
#  ('shiba_inu', 'japanese_chin', 7),
#  ('Abyssinian', 'keeshond', 6),
#  ('Bombay', 'japanese_chin', 6),
#  ('Bombay', 'scottish_terrier', 6),
#  ('British_Shorthair', 'japanese_chin', 6),
#  ('Egyptian_Mau', 'keeshond', 6),
#  ('Persian', 'leonberger', 6),
#  ('Siamese', 'leonberger', 6),
#  ('american_pit_bull_terrier', 'Egyptian_Mau', 6),
#  ('basset_hound', 'havanese', 6),
#  ('english_cocker_spaniel', 'scottish_terrier', 6),
#  ('german_shorthaired', 'beagle', 6),
#  ('great_pyrenees', 'wheaten_terrier', 6),
#  ('pomeranian', 'Maine_Coon', 6),
#  ('shiba_inu', 'saint_bernard', 6),
#  ('yorkshire_terrier', 'Maine_Coon', 6),
#  ('Bengal', 'pomeranian', 5),
#  ('Egyptian_Mau', 'pomeranian', 5),
#  ('Ragdoll', 'staffordshire_bull_terrier', 5),
#  ('Siamese', 'samoyed', 5),
#  ('Sphynx', 'Bombay', 5),
#  ('american_bulldog', 'Bombay', 5),
#  ('american_bulldog', 'miniature_pinscher', 5),
#  ('american_bulldog', 'newfoundland', 5),
#  ('beagle', 'keeshond', 5),
#  ('english_setter', 'shiba_inu', 5),
#  ('german_shorthaired', 'great_pyrenees', 5),
#  ('havanese', 'Bombay', 5),
#  ('japanese_chin', 'Maine_Coon', 5),
#  ('newfoundland', 'german_shorthaired', 5),
#  ('newfoundland', 'havanese', 5),
#  ('pug', 'miniature_pinscher', 5),
#  ('samoyed', 'pomeranian', 5),
#  ('scottish_terrier', 'Bombay', 5),
#  ('shiba_inu', 'yorkshire_terrier', 5),
#  ('staffordshire_bull_terrier', 'newfoundland', 5),
#  ('wheaten_terrier', 'american_bulldog', 5),
#  ('Bengal', 'Russian_Blue', 4),
#  ('Maine_Coon', 'japanese_chin', 4),
#  ('Maine_Coon', 'pomeranian', 4),
#  ('Persian', 'german_shorthaired', 4),
#  ('Persian', 'keeshond', 4),
#  ('Ragdoll', 'leonberger', 4),
#  ('Siamese', 'Bombay', 4),
#  ('Siamese', 'boxer', 4),
#  ('Sphynx', 'newfoundland', 4),
#  ('american_bulldog', 'american_pit_bull_terrier', 4),
#  ('american_pit_bull_terrier', 'Siamese', 4),
#  ('basset_hound', 'american_bulldog', 4),
#  ('beagle', 'Siamese', 4),
#  ('boxer', 'Egyptian_Mau', 4),
#  ('boxer', 'Russian_Blue', 4),
#  ('chihuahua', 'newfoundland', 4),
#  ('english_cocker_spaniel', 'Maine_Coon', 4),
#  ('great_pyrenees', 'Persian', 4),
#  ('great_pyrenees', 'pomeranian', 4),
#  ('havanese', 'Maine_Coon', 4),
#  ('japanese_chin', 'Russian_Blue', 4),
#  ('japanese_chin', 'wheaten_terrier', 4),
#  ('keeshond', 'miniature_pinscher', 4),
#  ('keeshond', 'pomeranian', 4),
#  ('leonberger', 'Sphynx', 4),
#  ('miniature_pinscher', 'Egyptian_Mau', 4),
#  ('newfoundland', 'miniature_pinscher', 4),
#  ('pomeranian', 'miniature_pinscher', 4),
#  ('saint_bernard', 'american_bulldog', 4),
#  ('samoyed', 'Bengal', 4),
#  ('samoyed', 'wheaten_terrier', 4),
#  ('scottish_terrier', 'wheaten_terrier', 4),
#  ('yorkshire_terrier', 'Birman', 4),
#  ('Abyssinian', 'japanese_chin', 3),
#  ('Bengal', 'British_Shorthair', 3),
#  ('Bengal', 'keeshond', 3),
#  ('Birman', 'Russian_Blue', 3),
#  ('Birman', 'beagle', 3),
#  ('Birman', 'miniature_pinscher', 3),
#  ('Birman', 'newfoundland', 3),
#  ('Birman', 'wheaten_terrier', 3),
#  ('Bombay', 'Russian_Blue', 3),
#  ('British_Shorthair', 'Abyssinian', 3),
#  ('British_Shorthair', 'Ragdoll', 3),
#  ('British_Shorthair', 'Sphynx', 3),
#  ('British_Shorthair', 'boxer', 3),
#  ('Egyptian_Mau', 'Russian_Blue', 3),
#  ('Egyptian_Mau', 'german_shorthaired', 3),
#  ('Egyptian_Mau', 'japanese_chin', 3),
#  ('Egyptian_Mau', 'shiba_inu', 3),
#  ('Egyptian_Mau', 'staffordshire_bull_terrier', 3),
#  ('Maine_Coon', 'British_Shorthair', 3),
#  ('Maine_Coon', 'Sphynx', 3),
#  ('Maine_Coon', 'boxer', 3),
#  ('Maine_Coon', 'keeshond', 3),
#  ('Persian', 'pomeranian', 3),
#  ('Ragdoll', 'american_bulldog', 3),
#  ('Russian_Blue', 'pug', 3),
#  ('Russian_Blue', 'yorkshire_terrier', 3),
#  ('Siamese', 'american_bulldog', 3),
#  ('Sphynx', 'keeshond', 3),
#  ('Sphynx', 'pomeranian', 3),
#  ('american_bulldog', 'basset_hound', 3),
#  ('american_bulldog', 'great_pyrenees', 3),
#  ('american_bulldog', 'scottish_terrier', 3),
#  ('american_pit_bull_terrier', 'Bombay', 3),
#  ('american_pit_bull_terrier', 'miniature_pinscher', 3),
#  ('basset_hound', 'Siamese', 3),
#  ('basset_hound', 'miniature_pinscher', 3),
#  ('beagle', 'Persian', 3),
#  ('beagle', 'american_bulldog', 3),
#  ('beagle', 'scottish_terrier', 3),
#  ('beagle', 'shiba_inu', 3),
#  ('chihuahua', 'Abyssinian', 3),
#  ('chihuahua', 'Maine_Coon', 3),
#  ('chihuahua', 'Persian', 3),
#  ('chihuahua', 'german_shorthaired', 3),
#  ('english_setter', 'boxer', 3),
#  ('english_setter', 'pug', 3),
#  ('english_setter', 'saint_bernard', 3),
#  ('english_setter', 'scottish_terrier', 3),
#  ('german_shorthaired', 'Birman', 3),
#  ('german_shorthaired', 'japanese_chin', 3),
#  ('great_pyrenees', 'german_shorthaired', 3),
#  ('havanese', 'Persian', 3),
#  ('havanese', 'german_shorthaired', 3),
#  ('havanese', 'samoyed', 3),
#  ('japanese_chin', 'beagle', 3),
#  ('japanese_chin', 'miniature_pinscher', 3),
#  ('keeshond', 'american_pit_bull_terrier', 3),
#  ('miniature_pinscher', 'Birman', 3),
#  ('miniature_pinscher', 'Persian', 3),
#  ('miniature_pinscher', 'boxer', 3),
#  ('miniature_pinscher', 'newfoundland', 3),
#  ('newfoundland', 'Persian', 3),
#  ('newfoundland', 'great_pyrenees', 3),
#  ('pomeranian', 'boxer', 3),
#  ('pomeranian', 'english_cocker_spaniel', 3),
#  ('pomeranian', 'keeshond', 3),
#  ('pug', 'saint_bernard', 3),
#  ('samoyed', 'saint_bernard', 3),
#  ('shiba_inu', 'pomeranian', 3),
#  ('staffordshire_bull_terrier', 'Persian', 3),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 3),
#  ('wheaten_terrier', 'Maine_Coon', 3),
#  ('wheaten_terrier', 'Persian', 3),
#  ('wheaten_terrier', 'boxer', 3),
#  ('wheaten_terrier', 'japanese_chin', 3),
#  ('wheaten_terrier', 'pug', 3),
#  ('wheaten_terrier', 'samoyed', 3),
#  ('yorkshire_terrier', 'Russian_Blue', 3),
#  ('yorkshire_terrier', 'great_pyrenees', 3)]

# %% [markdown]
# ## Other data formats

# %%
path = untar_data(URLs.MNIST_SAMPLE); path
# Out:
# PosixPath('/home/jupyter/.fastai/data/mnist_sample')

# %%
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=26)

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
learn = create_cnn(data, models.resnet18, metrics=accuracy)
learn.fit(2)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /home/jupyter/.torch/models/resnet18-5c106cde.pth
# 100%|██████████| 46827520/46827520 [00:00<00:00, 85009396.25it/s]
# Total time: 00:22 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.172076</th>
#     <th>0.081527</th>
#     <th>0.973994</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.106294</th>
#     <th>0.046319</th>
#     <th>0.982826</th>
#   </tr>
# </table>

# %%
df = pd.read_csv(path/'labels.csv')
df.head()
# Out:
#                 name  label
# 0   train/3/7463.png      0
# 1  train/3/21102.png      0
# 2  train/3/31559.png      0
# 3  train/3/46882.png      0
# 4  train/3/26209.png      0

# %%
data = ImageDataBunch.from_csv(path, ds_tfms=tfms, size=28)

# %%
data.show_batch(rows=3, figsize=(5,5))
data.classes
# Out:
# [0, 1]

# %%
data = ImageDataBunch.from_df(path, df, ds_tfms=tfms, size=24)
data.classes
# Out:
# [0, 1]

# %%
fn_paths = [path/name for name in df['name']]; fn_paths[:2]
# Out:
# [PosixPath('/home/jupyter/.fastai/data/mnist_sample/train/3/7463.png'),
#  PosixPath('/home/jupyter/.fastai/data/mnist_sample/train/3/21102.png')]

# %%
pat = r"/(\d)/\d+\.png$"
data = ImageDataBunch.from_name_re(path, fn_paths, pat=pat, ds_tfms=tfms, size=24)
data.classes
# Out:
# ['3', '7']

# %%
data = ImageDataBunch.from_name_func(path, fn_paths, ds_tfms=tfms, size=24,
        label_func = lambda x: '3' if '/3/' in str(x) else '7')
data.classes
# Out:
# ['3', '7']

# %%
labels = [('3' if '/3/' in str(x) else '7') for x in fn_paths]
labels[:5]
# Out:
# ['3', '3', '3', '3', '3']

# %%
data = ImageDataBunch.from_lists(path, fn_paths, labels=labels, ds_tfms=tfms, size=24)
data.classes
# Out:
# ['3', '7']
